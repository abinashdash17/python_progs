# %%
import numpy as np
from matplotlib import pyplot as plt,animation

# %% [markdown]
# ![single_layer_perceptron.jpg](attachment:single_layer_perceptron.jpg)

# %%
class1_x_y = [-5,-5]
class1_variance = 1
class2_x_y = [5,0]
class2_variance = 3

mean = np.array(class1_x_y)
cov = np.array([[class1_variance,0],[0,class1_variance]])
set1 = np.random.multivariate_normal(mean, cov, 500)

mean = np.array(class2_x_y)
cov = np.array([[class2_variance,0],[0,class2_variance]])
set2 = np.random.multivariate_normal(mean, cov, 500)


train_data = np.concatenate((set1,set2),axis=0)
y_actual = np.hstack((np.ones(set1.shape[0]),-1 * np.ones(set2.shape[0])))

train_data = np.column_stack((train_data,np.ones(train_data.shape[0]))) #add bias columnn



# weight = np.array([1,5,0])
weight = np.random.rand(3)
print(train_data.shape)
print(weight.shape)
# print((err * dataset).shape)
# print((err * dataset).shape)

N=30
eta = 0.005
error_data = np.zeros((N,dataset.shape[0]))
for j in range(0,N):
    for i in range(train_data.shape[0]):
        error_data[j,i] = y_actual[i] - np.sign((np.dot(train_data[i,:],weight)))
        weight = weight + eta * (error_data[j,i] * train_data[i,:])
error_data = error_data.reshape(N * train_data.shape[0])
plt.plot(np.arange(error_data.size),error_data)
plt.show()
# Out:
# (1000, 3)
# (3,)

# %%
test_data_x_y = [5,0]
test_data_variance = 25
test_data_count = 2000
mean = np.array(test_data_x_y)
cov = np.array([[test_data_variance,0],[0,test_data_variance]])
set3 = np.random.multivariate_normal(mean, cov, test_data_count)
test_data = np.column_stack((set3,np.ones(set3.shape[0]))) #add bias columnn
result = np.sign(np.dot(test_data,weight))
class1 = test_data[result > 0]
class2 = test_data[result < 0]
print(weight)

#decision line
x = np.arange(-10,10,0.2)
y = -1 * (weight[0] * x + weight [2]) / weight[1]

# plt.xlim([-5, 10])
plt.ylim([-25, 25])
plt.scatter(set1[:,0],set1[:,1],color='red')
plt.scatter(set2[:,0],set2[:,1],color='blue')
plt.scatter(class1[:,0],class1[:,1],color='cyan',alpha=0.2)
plt.scatter(class2[:,0],class2[:,1],color='yellow',alpha=0.2)
plt.plot(x,y,'b-')
plt.show()
# Out:
# [-0.217336    0.00933022 -0.03005242]

# %%
x = np.arange(-10,10,0.25,dtype='float')
y_data = []
for i in np.arange(-5,5,0.25):
    y_data = 
    y = x*2 - 5
fig, ax = plt.subplots()
line1 = ax.plot() 
def update(frame):
    c = frame
    fig.
    pass

ani = animation.FuncAnimation(fig=fig, func=update, frames=10, interval=30)
plt.show()
# Out:
#   Cell In[55], line 4
#     y_data =
#              ^
# SyntaxError: invalid syntax

# %%
np.random.rand(3)
# Out:
# array([0.62931395, 0.29749472, 0.67467772])
